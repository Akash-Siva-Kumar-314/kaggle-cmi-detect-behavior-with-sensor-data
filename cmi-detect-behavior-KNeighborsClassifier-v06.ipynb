# %%
# Importing needed libraries
import numpy as np
import pandas as pd
import sklearn as sk

# %%
# Here it ouputs an array

# Using a funtion to contain our code snippet
def predict():  
    # Loading the CSV file
    file_path = 'D:/kaggle-cmi-detect-behavior-with-sensor-data/cmi-detect-behavior-with-sensor-data/train.csv'

    # Reading the CSV file
    df_original_data = pd.read_csv(file_path)

    # Display the first few rows of the dataframe, we will be doing this as checking step every step along the way
    #df_original_data.head()

    # Checking number of null values in each column
    #df_original_data.isnull().sum()

    # Defining feature and target
    A = df_original_data.iloc[:, 9:].values
    b = df_original_data.iloc[:, 8].values

    #print(A)
    #print(b)

    # Now the feature column has some null values - imputing them with a constant value Zero    
    # Replace NaNs with 0
    A = df_original_data.iloc[:, 9:].values
    A = np.nan_to_num(A, nan=0)
    #print(A[:5])  # Display first 5 rows

    # Scaling
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    A_train_s = sc.fit_transform(A)

    # Instead of test train split, using whole of the data to train our model.

    # Fitting KNN to the training set

    from sklearn.neighbors import KNeighborsClassifier
    classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
    classifier.fit(A_train_s, b)

    # Importing the testing data 

    # Loading the CSV file
    file_path_test = 'D:/kaggle-cmi-detect-behavior-with-sensor-data/cmi-detect-behavior-with-sensor-data/test.csv'
    
    # Reading the CSV file
    df_original_test_data = pd.read_csv(file_path_test)

    # Display the first few rows of the dataframe, we will be doing this as checking step every step along the way
    #df_original_test_data.head()

    # Only taking needed columns from test data
    original_test_data = df_original_test_data.iloc[:, 4:].values
    #print(original_test_data)

    # Predicting the test set - results
    y_pred = classifier.predict(original_test_data)
    #print(y_pred)
    
    return y_pred

    # ~ End of code.

# %%
predict()
# Out:
# array(['Wave hello', 'Wave hello', 'Wave hello', 'Wave hello',
#        'Wave hello', 'Wave hello', 'Wave hello', 'Wave hello',
#        'Wave hello', 'Cheek - pinch skin', 'Wave hello', 'Wave hello',
#        'Wave hello', 'Wave hello', 'Cheek - pinch skin',
#        'Cheek - pinch skin', 'Cheek - pinch skin', 'Cheek - pinch skin',
#        'Cheek - pinch skin', 'Cheek - pinch skin', 'Cheek - pinch skin',
#        'Cheek - pinch skin', 'Cheek - pinch skin', 'Cheek - pinch skin',
#        'Cheek - pinch skin', 'Cheek - pinch skin', 'Cheek - pinch skin',
#        'Cheek - pinch skin', 'Cheek - pinch skin', 'Cheek - pinch skin',
#        'Cheek - pinch skin', 'Cheek - pinch skin', 'Cheek - pinch skin',
#        'Cheek - pinch skin', 'Cheek - pinch skin', 'Cheek - pinch skin',
#        'Cheek - pinch skin', 'Cheek - pinch skin', 'Cheek - pinch skin',
#        'Cheek - pinch skin', 'Cheek - pinch skin', 'Cheek - pinch skin',
#        'Cheek - pinch skin', 'Cheek - pinch skin', 'Cheek - pinch skin',
#        'Cheek - pinch skin', 'Cheek - pinch skin',
#        'Pull air toward your face', 'Neck - scratch', 'Write name in air',
#        'Cheek - pinch skin', 'Neck - scratch',
#        'Pull air toward your face', 'Neck - scratch',
#        'Cheek - pinch skin', 'Cheek - pinch skin',
#        'Pull air toward your face', 'Pull air toward your face',
#        'Write name in air', 'Text on phone', 'Text on phone',
#        'Text on phone', 'Text on phone', 'Text on phone', 'Text on phone',
#        'Wave hello', 'Pull air toward your face', 'Write name in air',
#        'Write name in air', 'Cheek - pinch skin', 'Wave hello',
#        'Wave hello', 'Above ear - pull hair', 'Cheek - pinch skin',
#        'Wave hello', 'Wave hello', 'Wave hello',
#        'Pull air toward your face', 'Pull air toward your face',
#        'Pull air toward your face', 'Pull air toward your face',
#        'Pull air toward your face', 'Forehead - pull hairline',
#        'Forehead - pull hairline', 'Forehead - pull hairline',
#        'Forehead - pull hairline', 'Write name in air',
#        'Forehead - pull hairline', 'Forehead - pull hairline',
#        'Pull air toward your face', 'Forehead - pull hairline',
#        'Forehead - pull hairline', 'Pull air toward your face',
#        'Forehead - pull hairline', 'Forehead - pull hairline',
#        'Pull air toward your face', 'Forehead - pull hairline',
#        'Forehead - pull hairline', 'Forehead - pull hairline',
#        'Forehead - pull hairline', 'Forehead - pull hairline',
#        'Forehead - pull hairline', 'Forehead - pull hairline',
#        'Forehead - pull hairline', 'Pull air toward your face',
#        'Forehead - pull hairline', 'Pull air toward your face'],
#       dtype=object)

# %%
# Here it outputs a string

# Using a funtion to contain our code snippet
def predict():  
    # Loading the CSV file
    file_path = 'D:/kaggle-cmi-detect-behavior-with-sensor-data/cmi-detect-behavior-with-sensor-data/train.csv'

    # Reading the CSV file
    df_original_data = pd.read_csv(file_path)

    # Display the first few rows of the dataframe, we will be doing this as checking step every step along the way
    #df_original_data.head()

    # Checking number of null values in each column
    #df_original_data.isnull().sum()

    # Defining feature and target
    A = df_original_data.iloc[:, 9:].values
    b = df_original_data.iloc[:, 8].values

    #print(A)
    #print(b)

    # Now the feature column has some null values - imputing them with a constant value Zero    
    # Replace NaNs with 0
    A = df_original_data.iloc[:, 9:].values
    A = np.nan_to_num(A, nan=0)
    #print(A[:5])  # Display first 5 rows

    # Scaling
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    A_train_s = sc.fit_transform(A)

    # Instead of test train split, using whole of the data to train our model.

    # Fitting KNN to the training set

    from sklearn.neighbors import KNeighborsClassifier
    classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
    classifier.fit(A_train_s, b)

    # Importing the testing data 

    # Loading the CSV file
    file_path_test = 'D:/kaggle-cmi-detect-behavior-with-sensor-data/cmi-detect-behavior-with-sensor-data/test.csv'
    
    # Reading the CSV file
    df_original_test_data = pd.read_csv(file_path_test)

    # Display the first few rows of the dataframe, we will be doing this as checking step every step along the way
    #df_original_test_data.head()

    # Only taking needed columns from test data
    original_test_data = df_original_test_data.iloc[:, 4:].values
    #print(original_test_data)

    # Predicting the test set - results
    y_pred = classifier.predict(original_test_data)
    #print(y_pred)

    # Convert array of predictions to comma-separated string
    y_pred_string = ', '.join(y_pred.astype(str))

    return y_pred_string

    # ~ End of code.

# %%
predict()
# Out:
# 'Wave hello, Wave hello, Wave hello, Wave hello, Wave hello, Wave hello, Wave hello, Wave hello, Wave hello, Cheek - pinch skin, Wave hello, Wave hello, Wave hello, Wave hello, Cheek - pinch skin, Cheek - pinch skin, Cheek - pinch skin, Cheek - pinch skin, Cheek - pinch skin, Cheek - pinch skin, Cheek - pinch skin, Cheek - pinch skin, Cheek - pinch skin, Cheek - pinch skin, Cheek - pinch skin, Cheek - pinch skin, Cheek - pinch skin, Cheek - pinch skin, Cheek - pinch skin, Cheek - pinch skin, Cheek - pinch skin, Cheek - pinch skin, Cheek - pinch skin, Cheek - pinch skin, Cheek - pinch skin, Cheek - pinch skin, Cheek - pinch skin, Cheek - pinch skin, Cheek - pinch skin, Cheek - pinch skin, Cheek - pinch skin, Cheek - pinch skin, Cheek - pinch skin, Cheek - pinch skin, Cheek - pinch skin, Cheek - pinch skin, Cheek - pinch skin, Pull air toward your face, Neck - scratch, Write name in air, Cheek - pinch skin, Neck - scratch, Pull air toward your face, Neck - scratch, Cheek - pinch skin, Cheek - pinch skin, Pull air toward your face, Pull air toward your face, Write name in air, Text on phone, Text on phone, Text on phone, Text on phone, Text on phone, Text on phone, Wave hello, Pull air toward your face, Write name in air, Write name in air, Cheek - pinch skin, Wave hello, Wave hello, Above ear - pull hair, Cheek - pinch skin, Wave hello, Wave hello, Wave hello, Pull air toward your face, Pull air toward your face, Pull air toward your face, Pull air toward your face, Pull air toward your face, Forehead - pull hairline, Forehead - pull hairline, Forehead - pull hairline, Forehead - pull hairline, Write name in air, Forehead - pull hairline, Forehead - pull hairline, Pull air toward your face, Forehead - pull hairline, Forehead - pull hairline, Pull air toward your face, Forehead - pull hairline, Forehead - pull hairline, Pull air toward your face, Forehead - pull hairline, Forehead - pull hairline, Forehead - pull hairline, Forehead - pull hairline, Forehead - pull hairline, Forehead - pull hairline, Forehead - pull hairline, Forehead - pull hairline, Pull air toward your face, Forehead - pull hairline, Pull air toward your face'

# %%
# Here only one sequence of input was fed/simulated as needed for competition and output in string format. (Assuming sequence of input is one by one, I might be wrong)

# Using a funtion to contain our code snippet
def predict():  
    # Loading the CSV file
    file_path = 'D:/kaggle-cmi-detect-behavior-with-sensor-data/cmi-detect-behavior-with-sensor-data/train.csv'

    # Reading the CSV file
    df_original_data = pd.read_csv(file_path)

    # Display the first few rows of the dataframe, we will be doing this as checking step every step along the way
    #df_original_data.head()

    # Checking number of null values in each column
    #df_original_data.isnull().sum()

    # Defining feature and target
    A = df_original_data.iloc[:, 9:].values
    b = df_original_data.iloc[:, 8].values

    #print(A)
    #print(b)

    # Now the feature column has some null values - imputing them with a constant value Zero    
    # Replace NaNs with 0
    A = df_original_data.iloc[:, 9:].values
    A = np.nan_to_num(A, nan=0)
    #print(A[:5])  # Display first 5 rows

    # Scaling
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    A_train_s = sc.fit_transform(A)

    # Instead of test train split, using whole of the data to train our model.

    # Fitting KNN to the training set

    from sklearn.neighbors import KNeighborsClassifier
    classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
    classifier.fit(A_train_s, b)

    # Importing the testing data 

    # Loading the CSV file
    #file_path_test = 'D:/kaggle-cmi-detect-behavior-with-sensor-data/cmi-detect-behavior-with-sensor-data/test.csv'
    file_path_test = 'D:/kaggle-cmi-detect-behavior-with-sensor-data/cmi-detect-behavior-with-sensor-data/test_onetestcase.csv' # Using only one test case
    
    # Reading the CSV file
    df_original_test_data = pd.read_csv(file_path_test)

    # Display the first few rows of the dataframe, we will be doing this as checking step every step along the way
    #df_original_test_data.head()

    # Only taking needed columns from test data
    original_test_data = df_original_test_data.iloc[:, 4:].values
    #print(original_test_data)

    # Predicting the test set - results
    y_pred = classifier.predict(original_test_data)
    #print(y_pred)

    y_pred_string = str(y_pred[0]) # Converting the return value to a string.

    return y_pred_string

    # ~ End of code.

# %%
predict()
# Out:
# 'Wave hello'

# %%
# LET'S TRY RETURNING IT AS A PANDAS DATAFRAME, I think i am on the right track yipee.

# Using a funtion to contain our code snippet
def predict():  
    # Loading the CSV file
    file_path = 'D:/kaggle-cmi-detect-behavior-with-sensor-data/cmi-detect-behavior-with-sensor-data/train.csv'

    # Reading the CSV file
    df_original_data = pd.read_csv(file_path)

    # Display the first few rows of the dataframe, we will be doing this as checking step every step along the way
    #df_original_data.head()

    # Checking number of null values in each column
    #df_original_data.isnull().sum()

    # Defining feature and target
    A = df_original_data.iloc[:, 9:].values
    b = df_original_data.iloc[:, 8].values

    #print(A)
    #print(b)

    # Now the feature column has some null values - imputing them with a constant value Zero    
    # Replace NaNs with 0
    A = df_original_data.iloc[:, 9:].values
    A = np.nan_to_num(A, nan=0)
    #print(A[:5])  # Display first 5 rows

    # Scaling
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    A_train_s = sc.fit_transform(A)

    # Instead of test train split, using whole of the data to train our model.

    # Fitting KNN to the training set

    from sklearn.neighbors import KNeighborsClassifier
    classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
    classifier.fit(A_train_s, b)

    # Importing the testing data 

    # Loading the CSV file
    file_path_test = 'D:/kaggle-cmi-detect-behavior-with-sensor-data/cmi-detect-behavior-with-sensor-data/test.csv'
    
    # Reading the CSV file
    df_original_test_data = pd.read_csv(file_path_test)

    # Display the first few rows of the dataframe, we will be doing this as checking step every step along the way
    #df_original_test_data.head()

    # Only taking needed columns from test data
    original_test_data = df_original_test_data.iloc[:, 4:].values
    #print(original_test_data)

    # Predicting the test set - results
    y_pred = classifier.predict(original_test_data) # y_pred is an array
    
    # Convert predictions to DataFrame
    predictions_df = pd.DataFrame(y_pred, columns=['Predicted Behavior'])

    return predictions_df
    
    # ~ End of code.

# %%
predict()
# Out:
#             Predicted Behavior
# 0                   Wave hello
# 1                   Wave hello
# 2                   Wave hello
# 3                   Wave hello
# 4                   Wave hello
# ..                         ...
# 102   Forehead - pull hairline
# 103   Forehead - pull hairline
# 104  Pull air toward your face
# 105   Forehead - pull hairline
# 106  Pull air toward your face
#
# [107 rows x 1 columns]

# %%
pip install polars
# Out:
# Collecting polars
#   Downloading polars-1.31.0-cp39-abi3-win_amd64.whl.metadata (15 kB)
# Downloading polars-1.31.0-cp39-abi3-win_amd64.whl (35.2 MB)
#    ---------------------------------------- 0.0/35.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/35.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/35.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/35.2 MB 220.2 kB/s eta 0:02:40
#    ---------------------------------------- 0.1/35.2 MB 409.6 kB/s eta 0:01:26
#    ---------------------------------------- 0.3/35.2 MB 1.8 MB/s eta 0:00:19
#    - -------------------------------------- 1.0/35.2 MB 4.0 MB/s eta 0:00:09
#    -- ------------------------------------- 1.9/35.2 MB 6.9 MB/s eta 0:00:05
#    -- ------------------------------------- 1.9/35.2 MB 6.9 MB/s eta 0:00:05
#    -- ------------------------------------- 2.5/35.2 MB 6.8 MB/s eta 0:00:05
#    --- ------------------------------------ 3.5/35.2 MB 8.2 MB/s eta 0:00:04
#    ----- ---------------------------------- 4.7/35.2 MB 10.0 MB/s eta 0:00:04
#    ------ --------------------------------- 5.9/35.2 MB 11.0 MB/s eta 0:00:03
#    -------- ------------------------------- 7.1/35.2 MB 12.3 MB/s eta 0:00:03
#    --------- ------------------------------ 8.2/35.2 MB 13.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 9.4/35.2 MB 14.3 MB/s eta 0:00:02
#    ----------- ---------------------------- 10.4/35.2 MB 18.7 MB/s eta 0:00:02
#    ------------- -------------------------- 11.8/35.2 MB 21.8 MB/s eta 0:00:02
#    -------------- ------------------------- 12.9/35.2 MB 25.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 14.1/35.2 MB 26.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 15.6/35.2 MB 27.3 MB/s eta 0:00:01
#    ------------------- -------------------- 17.2/35.2 MB 28.4 MB/s eta 0:00:01
#    -------------------- ------------------- 18.4/35.2 MB 29.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 19.6/35.2 MB 28.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 20.7/35.2 MB 29.7 MB/s eta 0:00:01
#    ------------------------ --------------- 22.0/35.2 MB 28.5 MB/s eta 0:00:01
#    -------------------------- ------------- 23.1/35.2 MB 29.7 MB/s eta 0:00:01
#    --------------------------- ------------ 24.6/35.2 MB 29.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 25.8/35.2 MB 31.2 MB/s eta 0:00:01
#    ------------------------------ --------- 26.9/35.2 MB 28.5 MB/s eta 0:00:01
#    -------------------------------- ------- 28.6/35.2 MB 29.7 MB/s eta 0:00:01
#    --------------------------------- ------ 29.8/35.2 MB 31.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 31.0/35.2 MB 29.8 MB/s eta 0:00:01
#    ------------------------------------ --- 32.1/35.2 MB 29.7 MB/s eta 0:00:01
#    ------------------------------------- -- 33.3/35.2 MB 29.8 MB/s eta 0:00:01
#    ---------------------------------------  34.6/35.2 MB 29.8 MB/s eta 0:00:01
#    ---------------------------------------  35.2/35.2 MB 29.7 MB/s eta 0:00:01
#    ---------------------------------------  35.2/35.2 MB 29.7 MB/s eta 0:00:01
#    ---------------------------------------- 35.2/35.2 MB 23.3 MB/s eta 0:00:00
# Installing collected packages: polars
# Successfully installed polars-1.31.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import polars as pl

# %%
# LET'S TRY RETURNING IT AS A POLARS DATAFRAME

# Using a funtion to contain our code snippet
def predict():  
    # Loading the CSV file
    file_path = 'D:/kaggle-cmi-detect-behavior-with-sensor-data/cmi-detect-behavior-with-sensor-data/train.csv'

    # Reading the CSV file
    df_original_data = pd.read_csv(file_path)

    # Display the first few rows of the dataframe, we will be doing this as checking step every step along the way
    #df_original_data.head()

    # Checking number of null values in each column
    #df_original_data.isnull().sum()

    # Defining feature and target
    A = df_original_data.iloc[:, 9:].values
    b = df_original_data.iloc[:, 8].values

    #print(A)
    #print(b)

    # Now the feature column has some null values - imputing them with a constant value Zero    
    # Replace NaNs with 0
    A = df_original_data.iloc[:, 9:].values
    A = np.nan_to_num(A, nan=0)
    #print(A[:5])  # Display first 5 rows

    # Scaling
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    A_train_s = sc.fit_transform(A)

    # Instead of test train split, using whole of the data to train our model.

    # Fitting KNN to the training set

    from sklearn.neighbors import KNeighborsClassifier
    classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
    classifier.fit(A_train_s, b)

    # Importing the testing data 

    # Loading the CSV file
    file_path_test = 'D:/kaggle-cmi-detect-behavior-with-sensor-data/cmi-detect-behavior-with-sensor-data/test.csv'
    
    # Reading the CSV file
    df_original_test_data = pd.read_csv(file_path_test)

    # Display the first few rows of the dataframe, we will be doing this as checking step every step along the way
    #df_original_test_data.head()

    # Only taking needed columns from test data
    original_test_data = df_original_test_data.iloc[:, 4:].values
    #print(original_test_data)

    # Predicting the test set - results
    y_pred = classifier.predict(original_test_data) # y_pred is an array
    
    # Convert predictions to Polars DataFrame
    predictions_df = pl.DataFrame({'Predicted Behavior': y_pred})

    return predictions_df
    
    # ~ End of code.

# %%
predict()
# Out:
# shape: (107, 1)
# ┌───────────────────────────┐
# │ Predicted Behavior        │
# │ ---                       │
# │ str                       │
# ╞═══════════════════════════╡
# │ Wave hello                │
# │ Wave hello                │
# │ Wave hello                │
# │ Wave hello                │
# │ Wave hello                │
# │ …                         │
# │ Forehead - pull hairline  │
# │ Forehead - pull hairline  │
# │ Pull air toward your face │
# │ Forehead - pull hairline  │
# │ Pull air toward your face │
# └───────────────────────────┘

# %%
# LET'S TRY saving it as parquet

# Using a funtion to contain our code snippet
def predict():  
    # Loading the CSV file
    file_path = 'D:/kaggle-cmi-detect-behavior-with-sensor-data/cmi-detect-behavior-with-sensor-data/train.csv'

    # Reading the CSV file
    df_original_data = pd.read_csv(file_path)

    # Display the first few rows of the dataframe, we will be doing this as checking step every step along the way
    #df_original_data.head()

    # Checking number of null values in each column
    #df_original_data.isnull().sum()

    # Defining feature and target
    A = df_original_data.iloc[:, 9:].values
    b = df_original_data.iloc[:, 8].values

    #print(A)
    #print(b)

    # Now the feature column has some null values - imputing them with a constant value Zero    
    # Replace NaNs with 0
    A = df_original_data.iloc[:, 9:].values
    A = np.nan_to_num(A, nan=0)
    #print(A[:5])  # Display first 5 rows

    # Scaling
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    A_train_s = sc.fit_transform(A)

    # Instead of test train split, using whole of the data to train our model.

    # Fitting KNN to the training set

    from sklearn.neighbors import KNeighborsClassifier
    classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
    classifier.fit(A_train_s, b)

    # Importing the testing data 

    # Loading the CSV file
    file_path_test = 'D:/kaggle-cmi-detect-behavior-with-sensor-data/cmi-detect-behavior-with-sensor-data/test.csv'
    
    # Reading the CSV file
    df_original_test_data = pd.read_csv(file_path_test)

    # Display the first few rows of the dataframe, we will be doing this as checking step every step along the way
    #df_original_test_data.head()

    # Only taking needed columns from test data
    original_test_data = df_original_test_data.iloc[:, 4:].values
    #print(original_test_data)

    # Predicting the test set - results
    y_pred = classifier.predict(original_test_data) # y_pred is an array
    
    # Convert to DataFrame
    y_pred_df = pd.DataFrame(y_pred, columns=["Prediction"])

    # Save to Parquet
    y_pred_df.to_parquet("y_pred_output.parquet", index=False)

    return y_pred_df
    
    # ~ End of code.

# %%
predict()
# Out:
#                     Prediction
# 0                   Wave hello
# 1                   Wave hello
# 2                   Wave hello
# 3                   Wave hello
# 4                   Wave hello
# ..                         ...
# 102   Forehead - pull hairline
# 103   Forehead - pull hairline
# 104  Pull air toward your face
# 105   Forehead - pull hairline
# 106  Pull air toward your face
#
# [107 rows x 1 columns]
